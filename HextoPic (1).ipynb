# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
import cv2
import numpy as np
import os

lst = [
]
# 2222222222222
# SIGN::forward: 709252 us
# 1.812970, 0.000471, 0.000000, 98.186508, 0.000047, 0.000000, 
# Index: 3]
print(len(lst))
lst2 = [[lst[x*96+i] for i in range(96)]for x in range(96)]

print(lst2)
# Out:
# 9216
# ...

# %%
img = np.zeros((96,96),dtype=np.uint8)

for i in range(96):
  for y in range(96):
    img[i][y] = lst2[i][y]
print(img.shape)

# img = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

print(img)
print(img.shape)
# Out:
# (96, 96)
# [[101 101 104 104 103 105 103 103 108 100 100 102 105 113 105 110 108 111
#   108 111 117 109 108 109 106 109 106 105 104 109 109 111 110 105 112 104
#   112 109 109 109 116 110 111 114 111 111 112 110 114 114 109 111 108 105
#   104 112 106 101 104 104  96 101  96  96  96  93  99  93  95  92  93  95
#    93  88  89  87  82  80  82  78  80  82  79  79  82  80  78  78  76  79
#    82  87  79  81  85  83]
#  [ 98  98  93  94  94  96 107  99 101  99 101 104 103 103 104 105 107 107
#   105 111 112 106 106 106 112 111 108 108 105 103 104 104 101 102 101 104
#   104 104 102 104 106 104  99 100 101 101  99 101 100 102  98  96  93  93
#    92  94  85  96  90  90  88  88  97  85  84  84  84  84  82  80  80  83
#    78  80  77  79  74  68  72  72  75  76  72  69  69  69  69  72  69  69
#    70  72  66  69  64  67]
#  [ 99 101  98  96  99  99 101 101 101 101 101 101  98 103 109 104 107 109
#   111 108 113 108 109 109 110 102 104 107 106 106 108 104 101 104 104 102
# ...

# %%
X = np.array(img, dtype="uint8")

# %%
X
# Out:
# array([[101, 101, 104, 104, 103, 105, 103, 103, 108, 100, 100, 102, 105,
#         113, 105, 110, 108, 111, 108, 111, 117, 109, 108, 109, 106, 109,
#         106, 105, 104, 109, 109, 111, 110, 105, 112, 104, 112, 109, 109,
#         109, 116, 110, 111, 114, 111, 111, 112, 110, 114, 114, 109, 111,
#         108, 105, 104, 112, 106, 101, 104, 104,  96, 101,  96,  96,  96,
#          93,  99,  93,  95,  92,  93,  95,  93,  88,  89,  87,  82,  80,
#          82,  78,  80,  82,  79,  79,  82,  80,  78,  78,  76,  79,  82,
#          87,  79,  81,  85,  83],
#        [ 98,  98,  93,  94,  94,  96, 107,  99, 101,  99, 101, 104, 103,
#         103, 104, 105, 107, 107, 105, 111, 112, 106, 106, 106, 112, 111,
#         108, 108, 105, 103, 104, 104, 101, 102, 101, 104, 104, 104, 102,
#         104, 106, 104,  99, 100, 101, 101,  99, 101, 100, 102,  98,  96,
#          93,  93,  92,  94,  85,  96,  90,  90,  88,  88,  97,  85,  84,
# ...

# %%
from PIL import Image as im
data = im.fromarray(img)
      
    # saving the final output 
    # as a PNG file
data.save('pic1.png')

# %%
from PIL import Image
  
# open method used to open different extension image file
im = Image.open(r"pic1.png") 
  
# This method will show image in any image viewer 
from IPython.display import Image
Image('pic1.png')

# %%
from PIL import Image
  
# open method used to open different extension image file
im = Image.open(r"pic1.png") 
  
# This method will show image in any image viewer 
from IPython.display import Image
Image('pic1.png')
